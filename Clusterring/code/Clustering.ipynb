# %%
# %pip install matplotlib
# %pip install seaborn

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Requirement already satisfied: matplotlib in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (3.5.1)
# Requirement already satisfied: packaging>=20.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib) (4.31.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib) (3.0.7)
# Requirement already satisfied: pillow>=6.2.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib) (1.22.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: six>=1.5 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Volumes/Farshid_SSD/Projects/ML_PATH/my_env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from seaborn) (1.22.3)
# Requirement already satisfied: matplotlib>=2.2 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from seaborn) (3.5.1)
# Requirement already satisfied: pandas>=0.23 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from seaborn) (1.4.1)
# Requirement already satisfied: scipy>=1.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from seaborn) (1.8.0)
# Requirement already satisfied: packaging>=20.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.7)
# Requirement already satisfied: cycler>=0.10 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.31.1)
# Requirement already satisfied: pillow>=6.2.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.4.0)
# Requirement already satisfied: pytz>=2020.1 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Volumes/Farshid_SSD/Projects/ML_PATH/my_env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <div dir=rtl >
# <h1>خوشه‌بندی</h1>
# خوشه‌بندی به دسته‌بندی اشیا‌ به گونه‌ای گفته می‌شود که اشیا موجود در هر دسته نسبت به دیگر اشیا سایر دسته‌ها شباهت بیشتری داشته باشند.
#
# <img src="https://drive.google.com/uc?id=1RDHbS2bWOKM4WAq7sGMhrVLLBxegNer0"></img>
#
# چند مورد از کاربردهای رایج این الگوریتم‌ها در زیر اشاره شده است:
# - فشرده‌سازی
# - سامانه‌های توصیه‌گر (recommender systemss)
# - دسته‌بندی بر اساس شباهت
#   - دسته‌بندی صفحات شبیه بهم وب (برای مثال گوگل نیوز)
#   - دسته‌بندی مشتریان بر اساس سلیقه خرید برای ارائه خدمت بهتر
# </div>

# %% [markdown]
# <div dir=rtl>
# <h2>داده‌های نمونه</h2>
# برای شروع کار، داده‌های تصادفی را تولید می‌کنیم.
#
# <font color='Red'> توجه: از تغییردادن متغییرها اجتناب کنید.  </font>
# </div>

# %%
from sklearn.datasets import make_blobs

X, y = make_blobs(random_state=42)
print(X.shape)
# Out:
# (100, 2)

# %%
plt.scatter(X[:, 0], X[:, 1])

# %% [markdown]
# <div dir=rtl>
# <h2>الگوریتم k-means</h2>
# <div>
# یکی از الگوریتم‌های ساده و نسبتاً پرکاربرد برای خوشه‌بندی الگوریتم k-means است. هدف ما در این تمرین پیاده‌سازی این الگوریتم نیست و فقط آَشنایی با آن است. برای استفاده از این الگوریتم و الگوریتم‌های دیگر خوشه‌بندی می‌توانید ماژول‌های <code>sklearn.cluster</code> را مشاهده کنید.</div>
# </div>

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42)

# %% [markdown]
# <div dir=rtl>
# خط کد بالا، این الگوریتم را پیاده‌سازی می‌کند. درآن <code>n_clusters</code> تعداد خوشه‌ها را مشخص می‌کند.
#
# <font color='Green'> پرسش: ما می‌توانیم برچسب‌های خوشه‌ی هر داده را در این الگوریتم داشته باشیم. قطعه کدی بنویسید که برچسب‌های هر کدام از داده‌ها را پرینت کند. این برچسب‌ها را در متغیر <code>labels</code> قرار دهید.  </font>
# </div>

# %%
# your code here
labels = kmeans.fit_predict(X)
labels
# Out:
# array([1, 0, 2, 0, 1, 0, 2, 0, 0, 2, 2, 1, 1, 2, 2, 1, 1, 2, 1, 1, 2, 1,
#        1, 2, 2, 2, 0, 1, 1, 1, 1, 0, 0, 1, 2, 2, 2, 2, 0, 0, 1, 2, 0, 2,
#        2, 0, 1, 1, 1, 0, 0, 0, 2, 1, 1, 1, 2, 2, 0, 2, 1, 0, 1, 0, 1, 1,
#        0, 1, 0, 0, 0, 1, 1, 2, 0, 1, 0, 1, 0, 0, 2, 0, 2, 1, 2, 2, 2, 0,
#        2, 0, 0, 0, 2, 0, 2, 2, 2, 0, 1, 2], dtype=int32)

# %% [markdown]
# <div dir=rtl>
# <h2>مشاهده نتیجه</h2>
# ما می‌توانیم نتیجه‌ی خوشه‌بندی را با قطعه کد زیر مشاهده کنیم. در این قطعه کد می‌توانیم پالت رنگی برای رسم را موارد متفاوتی قرار دهیم. در این کد ما از پالت رنگ‌های سرد استفاده کردیم.
#
# </dir>

# %%
plt.scatter(X[:, 0], X[:, 1], cmap=plt.cm.cool, c=labels)

# %% [markdown]
# <div dir=rtl>
# <h2>تعیین تعداد خوشه‌ها</h2>
# یکی از ضعف‌های الگوریتم k-means مشخص کردن تعداد خوشه‌هاست. در این مثال با مشاهده شکل توانسیم که تعداد خوشه‌ها را حدس بزنیم. اما در دنیای واقعی این کار قابل انجام نیست. یکی از راه‌ها کاهش بعد با استفاده از PCA است که در تمرین اول مشاهده کردید. روش دیگر استفاده از روش آرنج (elbow) است.
#
#
# <font color='Green'> پرسش: اگر تعداد خوشه‌ها را برای داده‌های قبل 2 در نظر بگیریم، نمودار قبلی را برای این حالت رسم کنید. دقت کنید که <code>random_state=42</code> باشد. </font>
# </div>

# %%
# your code here
kmeans = KMeans(n_clusters=2, random_state=42)
labels = kmeans.fit_predict(X)
plt.scatter(X[:, 0], X[:, 1], cmap=plt.cm.cool, c=labels)

# %% [markdown]
# <div dir=rtl>
# <h2>روش آرنج (elbow)</h2>
# شما در درس با روش آرنج آشنا شده‌اید.
#
# <font color='Green'> پرسش: روش آرنج را برای مقدار خوشه‌های 1 تا 10 حساب کنید و نمودار میزان تابع هزینه را برای هر خوشه رسم کنید. برای هر مرحله <code>random_state</code> را برابر با صفر در نظر بگیرید.
# </div>

# %%
# your code here
distortions = []
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, random_state=0)
    kmeans.fit(X)
    distortions.append(kmeans.inertia_)

fig = plt.figure(figsize=(15, 5))
plt.plot(range(1, 10), distortions, marker='o', linestyle='-', color='red', markersize=10, lw=3, markerfacecolor='black', markeredgecolor='white')
plt.grid(True)
plt.title('Elbow curve')
# Out:
# Text(0.5, 1.0, 'Elbow curve')

# %% [markdown]
# <div dir=rtl>
# <h2>خوشه‌بندی‌های پیچیده‌تر</h2>
# همیشه خوشه‌بندی‌ها به این صورت نیست. همچنین k-means تنها الگوریتم خوشه‌بندی نیست. در زیر توزیع‌های مختلف داده‌های مختلف با روش k-means رسم شده‌است.
#
#  شما می‌توانید مشاهده کنید که در کدام حالت این الگوریتم خوب عمل می‌کند.
#
# تمامی این‌ کدها از سند مطالب <code>sklearn</code> استفاده شده است. شما می‌توانید این اسناد را در <a href="https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_assumptions.html"> اینجا</a> مشاهده کنید.
#
#
# همچنین می‌توانید الگوریتم‌های دیگر را نیز در اسناد <code>sklearn</code> مشاهده کنید.
# </div>

# %%
sns.set_style('white')

plt.figure(figsize=(12, 12))

n_samples = 1500
random_state = 170
X, y = make_blobs(n_samples=n_samples, random_state=random_state)

# Incorrect number of clusters
y_pred = KMeans(n_clusters=2, random_state=random_state).fit_predict(X)

plt.subplot(221)
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title("Incorrect Number of Blobs")

# Anisotropicly distributed data
transformation = [[0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
X_aniso = np.dot(X, transformation)
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_aniso)

plt.subplot(222)
plt.scatter(X_aniso[:, 0], X_aniso[:, 1], c=y_pred)
plt.title("Anisotropicly Distributed Blobs")

# Different variance
X_varied, y_varied = make_blobs(
    n_samples=n_samples, cluster_std=[1.0, 2.5, 0.5], random_state=random_state
)
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_varied)

plt.subplot(223)
plt.scatter(X_varied[:, 0], X_varied[:, 1], c=y_pred)
plt.title("Unequal Variance")

# Unevenly sized blobs
X_filtered = np.vstack((X[y == 0][:500], X[y == 1][:100], X[y == 2][:10]))
y_pred = KMeans(n_clusters=3, random_state=random_state).fit_predict(X_filtered)

plt.subplot(224)
plt.scatter(X_filtered[:, 0], X_filtered[:, 1], c=y_pred)
plt.title("Unevenly Sized Blobs")

plt.show()

# %% [markdown]
# <div dir=rtl>
#
# <font color='Green'> پرسش: خوشه‌بندی اعداد
#
# مجموعه داده‌ی digits در زیر لود شده است. الگوریتم k-means را برای این مجموعه داده پیاده کنید. تعداد خوشه‌ها را برابر با 10 در نظر بگیرید. مراکز خوشه‌ها را نمایش دهید. برای این کار هر 64 عدد را به ماتریس 8 در 8 تبدیل کنید. پس از آن از plt.imshow استفاده کنید. آیا می‌توان با مرکز تشخیص داد برای کدام دسته از اعداد است؟
# </font>
#
#
# <font color='Green'> پرسش: استفاده از Isomap
#
# این الگوریتم نیز مانند PCA کار کاهش بعد را انجام میدهد. با استفاده از این الگوریتم (موجود در <code>sklean.manifold.Isomap</code>) داده‌ها را به داده‌هایی با بعد 2 تبدیل کنید. پس از آن دو نمودار رسم کنید. نمودار اول رنگ هر داده را با لیبل‌هایی که الگوریتم kmeans تولید کرده است تعیین کنید و نمودار دوم رنگ هر داده برابر با digits.target که همان لیبل کلاس است، فرض بگیرید. چه چیزی متوجه می‌شوید؟
# </font>
# </div>

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.data.shape

kmeans = KMeans(n_clusters=10, random_state=0)
clusters = kmeans.fit_predict(digits.data)
kmeans.cluster_centers_.shape
# Out:
# (10, 64)

# %%
fig, ax = plt.subplots(2, 5, figsize=(8, 3))
centers = kmeans.cluster_centers_.reshape(10, 8, 8)
for axi, center in zip(ax.flat, centers):
    axi.set(xticks=[], yticks=[])
    axi.imshow(center, interpolation='nearest', cmap=plt.cm.binary)

# %%
# plt.scatter(digits.data[:, 0], digits.data[:, 1], c=clusters, s=50, cmap='viridis')
from time import time
from sklearn.manifold import Isomap

def plot_embedding(X, y_plot, plot_number=0, title=None):
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)
    plt.figure(plot_number)
    ax = plt.subplot(111)
    for i in range(X.shape[0]):
        plt.text(X[i, 0], X[i, 1], str(y_plot[i]),
                 color=plt.cm.Set1(y_plot[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)
        
print("Computing Isomap embedding")
t0 = time()
X_iso = Isomap(n_components=2).fit_transform(digits.data)
y_pred_iso = KMeans(n_clusters=10, random_state=0).fit_predict(X_iso)
print("Done.")
plot_embedding(X_iso, 
               y_pred_iso,
               plot_number=0,
               title="Isomap projection of the digits (time %.2fs)" %
               (time() - t0))

plot_embedding(X_iso, 
               digits.target,
               plot_number=1,
               title="Target plot")
# Out:
# Computing Isomap embedding
# /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages/sklearn/manifold/_isomap.py:324: UserWarning: The number of connected components of the neighbors graph is 2 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages/scipy/sparse/_index.py:103: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# Done.

# %% [markdown]
# <div dir=rtl>
#
# <font color='Green'> پرسش: کاهش حجم عکس با kmeans
# </font>
#
# <font color='Green'>
# یکی از کاربردهای این الگوریتم کاهش حجم است. در تصویری که همراه با تمرین قرار داده شده است. شما تصویر یک پرنده را میبینید. در قطعه کد زیر (سومین قطعه کد) شما توزیع رنگی استفاده شده در این عکس را مشاهده می‌کنید. حال کاری که شما باید کنید این است که این رنگ‌ها را به 4 خوشه تقسیم کنید و به جای هر رنگ از مرکز آن خوشه استفاده کنید. سپس تصویر را با رنگ‌های جدید ترسیم کنید.
# </font>
#
# قطعه کد اول برای اتصال گوگل کولب به گوگل درایو شما است. در صورتی که از گوگل کولب استفاده نمیکنید، این قطعه کد را اجرا نکنید. قطعه کد دوم عکس را لود میکند. در ورودی تابع imread آدرس عکس را قرار دهید. اگر از گوگل کولب استفاده میکنید، باید ابتدا این عکس را در درایو خود آپلود کنید و آدرس آن را وارد کنید.
# </div>

# %%
# from google.colab import drive

# drive.mount('/content/gdrive')

# %%
from matplotlib.pyplot import imread

img = imread('/Volumes/Farshid_SSD/Projects/ML_PATH/Clusterring/data/bird.jpg')

# %%
fig = plt.figure(figsize=(10, 10))

ax = fig.add_subplot(111, projection='3d')

A = img.reshape((img.shape[0] *img.shape[1], 3))

ax.scatter3D(A[:, 0], A[:, 1], A[:, 2], color=A[:]/255.0)

# %%
# %pip install scikit-image

from skimage import io

io.imshow(img)
io.show()
# Out:
# Requirement already satisfied: scikit-image in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (0.19.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from scikit-image) (9.0.1)
# Requirement already satisfied: networkx>=2.2 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from scikit-image) (2.8.4)
# Requirement already satisfied: imageio>=2.4.1 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from scikit-image) (2.19.3)
# Requirement already satisfied: packaging>=20.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from scikit-image) (21.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from scikit-image) (2022.5.4)
# Requirement already satisfied: scipy>=1.4.1 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from scikit-image) (1.8.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from scikit-image) (1.3.0)
# Requirement already satisfied: numpy>=1.17.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from scikit-image) (1.22.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from packaging>=20.0->scikit-image) (3.0.7)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Volumes/Farshid_SSD/Projects/ML_PATH/my_env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
kMeans_image = KMeans(n_clusters=4, random_state=42)
clusters = kMeans_image.fit_predict(A)

k_colors = kMeans_image.cluster_centers_[kMeans_image.fit_predict(A)]
k_img = np.clip(k_colors.astype('uint8'), 0, 255)
k_img = np.reshape(k_img, (img.shape))


fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('K-means Image Compressor', fontsize=15)

ax1.set_title('Compressed Image')
ax1.set_xticks([])
ax1.set_yticks([])
ax1.imshow(k_img)

ax2.set_title('Original Image')
ax2.set_xticks([])
ax2.set_yticks([])
ax2.imshow(img)

plt.subplots_adjust(top=0.9)
plt.show()

# %% [markdown]
# <div dir=rtl >
# <h1>الگوریتم DBSCAN</h1>
#
# الگوریتم DBSCAN از دیگر الگوریتم‌های مورد استفاده برای خوشه‌بندی داده‌ها می‌باشد که می‌تواند داده‌هایی با شکل‌های مختلف را خوشه‌بندی کند و نویزها و ناهنجاری‌های موجود در داده‌ها را تشخیص دهد.
#
#  با توجه به مزیت گفته شده، در این بخش می‌خواهیم دو مجموعه داده‌ گفته شده در بخش "خوشه‌بندی‌های پیچیده‌تر" را با استفاده از الگوریتم DBSCAN مجدد  خوشه‌بندی کنیم.
#  مجموعه داده‌های
# <code> X_aniso</code> و <code>X_varied</code>
# را در نظر بگیرید.
#
#  برای اجرای الگوریتم DBSCAN نیازی به تعیین تعداد خوشه‌ها نیست و شما می‌بایست دو پارامتر اصلی این الگوریتم یعنی اپسیلون و حداقل تعداد نقاط هر خوشه را به نحوی تعیین کنید که خروجی شما دقیق‌تر شود.
#
#
# </div>

# %% [markdown]
# <div dir=rtl >
# <h1>تعیین اپسیلون</h1>
#
#  برای پیدا کردن بهترین اپسیلون متناسب با مجموعه داده، علاوه‌بر آزمودن مقادیر مختلف، از روش فاصله KNN (محاسبه میانگین فاصله بین هر نقطه و k نزدیک‌ترین همسایه آن) نیز برای تعیین خودکار مقدار اپسیلون بهینه استفاده می‌شود.
#
#  k در اینجا برابر است با حداقل تعداد نقاط در خوشه که همان معادل MinPts می‌باشد. برخلاف پارامتر اپسیلون، برای تعیین MinPts هیچ روش خودکاری وجود ندارد. اما با توجه به برخی ویژگی‌های مجموعه داده‌ها چند قانون کلی وجود دارد که می‌تواند در پیدا کردن محدوده مقادیر مناسب MinPts آن مجموعه داده به ما کمک کند.
#
# <font color='Green'> پرسش: علت استفاده از KNN برای پیدا کردن اپسیلون بهینه را شرح دهید. سپس با رسم گراف k-distance  و با پیروی از الگوی آرنج مقدار اپسیلون بهینه را   بدست آورید.
#
# <font color='Green'>  برای رسم گراف k-distace ‌می‌توانید از ماژول NearestNeighbors در کنابخانه Scikit-learn و برای مشخص کردن مقدار اپسیلون از کتابخانه kneed استفاده کنید.
#
#
#
# </div>

# %%
# %pip install kneed

from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics import v_measure_score
from kneed import KneeLocator
import pandas as pd
# Out:
# Requirement already satisfied: kneed in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (0.7.0)
# Requirement already satisfied: matplotlib in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from kneed) (3.5.1)
# Requirement already satisfied: scipy in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from kneed) (1.8.0)
# Requirement already satisfied: numpy>=1.14.2 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from kneed) (1.22.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib->kneed) (4.31.1)
# Requirement already satisfied: cycler>=0.10 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib->kneed) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib->kneed) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib->kneed) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib->kneed) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib->kneed) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from matplotlib->kneed) (3.0.7)
# Requirement already satisfied: six>=1.5 in /Volumes/Farshid_SSD/Projects/ML_PATH/my_env/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->kneed) (1.16.0)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Volumes/Farshid_SSD/Projects/ML_PATH/my_env/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
def knee_find(X, n_neighbors):
    neighbors = NearestNeighbors(n_neighbors=n_neighbors)
    neighbors_fit = neighbors.fit(X)
    distances, indices = neighbors_fit.kneighbors(X)

    distances = np.sort(distances, axis=0)
    distances = distances[:, -1]

    i = np.arange(len(distances))
    knee = KneeLocator(i, distances, curve='convex', direction='increasing', interp_method='polynomial')
    knee.plot_knee()
    plt.axhline(y=knee.elbow_y, color='r', linestyle='dotted')
    plt.show()

    print(knee.all_elbows_y, knee.all_elbows)

# %%
knee_find(X_varied, 10)
# Out:
# [0.7817728533355023] {1326}

# %%
knee_find(X_aniso, 20)
# Out:
# [0.3676484232513166] {1333}

# %% [markdown]
# مناسب ترین مقدار برای eps برای داده های ansio مقدار ۰.۱ است
#
# مناسب ترین مقدار برای eps برای داده های varid مقدار ۰.۲۸ است

# %% [markdown]
# <div dir=rtl >
# <h1>تعیین MinPts</h1>
#
# در مرحله قبل برای تعیین اپسیلون بهینه  مقدار MinPts را نیز مشخص کردیم. اما لزوما با آن مقدار  بهترین خوشه‌بندی را نخواهیم داشت.
#
# <font color='Green'> پرسش: در این مرحله با در نظر گرفتن اپسیلون بدست آمده و با آزمودن مقادیر مختلف برای  پارامتر MinPts، بهترین حالت برای خوشه‌بندی را با استفاده از رنگ‌بندی مناسب رسم کنید.
#
# </div>

# %%
# your code here
sns.set_style('white')

n_samples = 1500
random_state = 170

def plot_dbscan(X, eps, min_samples, title, plt):
    y_pred = DBSCAN(eps=eps, min_samples=min_samples).fit_predict(X)

    plt.scatter(X[:, 0], X[:, 1], c=y_pred)
    plt.set_title(title)
    # plt.set_xticks([])
    # plt.set_yticks([])

# %%
fig, axis = plt.subplots(2, 5, sharex=True, sharey = True, figsize=(25, 15))
fig.suptitle('Anisotropicly Distributed Blobs', fontsize=15)
for i in range(10):
    plot_dbscan(X_aniso, 0.35, i + 1, f'min_samples = {i + 1}', axis[i // 5, i % 5])

plt.subplots_adjust()
plt.show()
    
# plot_dbscan(X_varied, 0.8, 10, 222, "Unequal Variance")

# %%
fig, axis = plt.subplots(2, 5, sharex=True, sharey = True, figsize=(25, 15))
fig.suptitle('Anisotropicly Distributed Blobs', fontsize=15)
for i in range(5, 15):
    plot_dbscan(X_varied, 0.8, i + 1, f'min_samples = {i + 1}', axis[(i - 5) // 5, i % 5])
plt.subplots_adjust()
plt.show()

# %% [markdown]
# <div dir=rtl >
# <h1>بررسی نتایج</h1>
#
#
# <font color='Green'> پرسش: خوشه‌های حاصل از اعمال دو الگوریتم k-means و DBSCAN بر روی این دو مجموعه داده را با یکدیگر مقایسه کنید. چه نتیجه‌ای می‌گیرید؟
#
# </div>

# %% [markdown]
# <div dir=rtl>
# برای داده‌های x_ansio استفاده از DBScan بهتر است ولی برای داده‌های x_varied استفاده از kmeans. چرا؟ چون:
#
# وقتی داده‌ها جداپذیر خطی هستند، الگوریتم kmeans خیلی خوب داده‌ها را براساس فاصله آنها از یکدیگر جدا می‌کند. نکته kmeans همان k است، تعداد خوشه‌ها، که اگر زیادی بالا یا زیادی کم باشد دسته بندی ما بدردبخور نیست.
#
# وقتی داده‌ها به شکلهای عجیبتر کنار هم قرار گرفتند، بهترین راه دیگری که داریم استفاده از روش مبتنی بر چگالی DBSCAN است. اینجا چالش پیداکردن اپسیلون و minpoints درست است چراکه اگر زیاد انتخاب کنیم، تعداد کمی کلاستر بزرگ، و اگر کم انتخاب کنیم، کلاسترهای کوچک و متعدد میگیریم.
# </div>
